# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\hp\Desktop\Projects\Data-Projects\Online Sales Data.csv')

# %%
data.head()
# Out:
#   Transaction ID        Date Product Category             Product Name  \
# 0          10001  2024-01-01      Electronics            iPhone 14 Pro
# 1          10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2          10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3          10004  2024-01-04            Books        The Da Vinci Code
# 4          10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0         2.0      999.99        1999.98  North America    Credit Card
# 1         1.0      499.99         499.99         Europe         PayPal
# 2         3.0       69.99         209.97           Asia     Debit Card
# 3         4.0       15.99          63.96  North America    Credit Card
# 4         1.0       89.99          89.99         Europe         PayPal

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    240 non-null    object
#  1   Date              239 non-null    object
#  2   Product Category  239 non-null    object
#  3   Product Name      239 non-null    object
#  4   Units Sold        239 non-null    float64
#  5   Unit Price        239 non-null    float64
#  6   Total Revenue     239 non-null    float64
#  7   Region            239 non-null    object
#  8   Payment Method    239 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 17.0+ KB

# %%
data.shape
# Out:
# (240, 9)

# %%
data.isnull().sum()
# Out:
# Transaction ID      0
# Date                1
# Product Category    1
# Product Name        1
# Units Sold          1
# Unit Price          1
# Total Revenue       1
# Region              1
# Payment Method      1
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product Category    0
# Product Name        0
# Units Sold          0
# Unit Price          0
# Total Revenue       0
# Region              0
# Payment Method      0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#        Units Sold   Unit Price  Total Revenue
# count  239.000000   239.000000     239.000000
# mean     2.154812   237.234100     336.652218
# std      1.324101   430.151021     486.599209
# min      1.000000     6.500000       6.500000
# 25%      1.000000    29.500000      61.970000
# 50%      2.000000    89.990000     179.970000
# 75%      3.000000   249.990000     399.450000
# max     10.000000  3899.990000    3899.990000

# %%
data.count()
# Out:
# Transaction ID      240
# Date                239
# Product Category    239
# Product Name        239
# Units Sold          239
# Unit Price          239
# Total Revenue       239
# Region              239
# Payment Method      239
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# Length: 240, dtype: bool

# %% [markdown]
# # Analysis

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data['Total Revenue'].value_counts()
# Out:
# Total Revenue
# 299.99    5
# 499.99    4
# 399.99    4
# 149.95    4
# 259.98    4
#          ..
# 98.85     1
# 299.00    1
# 270.00    1
# 55.00     1
# 59.98     1
# Name: count, Length: 172, dtype: int64

# %%
data.hist(figsize=(20,15))
plt.show()

# %%
data.sample(6)
# Out:
#     Transaction ID        Date Product Category  \
# 97           10098  2024-04-07  Home Appliances
# 140          10141  2024-05-20         Clothing
# 223          10224  2024-08-11  Home Appliances
# 119          10120  2024-04-29           Sports
# 77           10078  2024-03-18           Sports
# 155          10156  2024-06-04           Sports
#
#                                  Product Name  Units Sold  Unit Price  \
# 97                  Vitamix Explorian Blender         1.0      349.99
# 140              Adidas Essential Track Pants         3.0       44.99
# 223  Philips Sonicare DiamondClean Toothbrush         2.0      229.99
# 119          YETI Hopper Flip Portable Cooler         1.0      249.99
# 77                   Rogue Fitness Kettlebell         3.0       69.99
# 155                     Garmin Forerunner 245         1.0      299.99
#
#      Total Revenue  Region Payment Method
# 97          349.99  Europe         PayPal
# 140         134.97    Asia     Debit Card
# ...

# %%
data.Region.value_counts().plot.pie(autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data.Region)
# Out:
# <Axes: xlabel='count', ylabel='Region'>

# %%
sns.histplot(data.Region)
# Out:
# <Axes: xlabel='Region', ylabel='Count'>

# %%
data.head()
